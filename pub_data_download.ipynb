# %%
import os

# %% [markdown]
# ### DIV2K

# %%
DATA_PATH = '/gpfs/gpfs0/b.shirokikh/data/SR/DIV2K/'

# %%
names = [
    'DIV2K_train_LR_bicubic_X2.zip',
    'DIV2K_train_LR_unknown_X2.zip',
    'DIV2K_valid_LR_bicubic_X2.zip',
    'DIV2K_valid_LR_unknown_X2.zip',
    'DIV2K_train_LR_bicubic_X3.zip',
    'DIV2K_train_LR_unknown_X3.zip',
    'DIV2K_valid_LR_bicubic_X3.zip',
    'DIV2K_valid_LR_unknown_X3.zip',
    'DIV2K_train_LR_bicubic_X4.zip',
    'DIV2K_train_LR_unknown_X4.zip',
    'DIV2K_valid_LR_bicubic_X4.zip',
    'DIV2K_valid_LR_unknown_X4.zip',
    'DIV2K_train_LR_x8.zip',
    'DIV2K_train_LR_mild.zip',
    'DIV2K_train_LR_difficult.zip',
    'DIV2K_train_LR_wild.zip',
    'DIV2K_valid_LR_x8.zip',
    'DIV2K_valid_LR_mild.zip',
    'DIV2K_valid_LR_difficult.zip',
    'DIV2K_valid_LR_wild.zip',
    'DIV2K_train_HR.zip',
    'DIV2K_valid_HR.zip',
]

# %%
for name in names:
    filename = os.path.join(DATA_PATH, name)
    if not os.path.exists(filename):
        # !wget -O {filename} -t inf http://data.vision.ee.ethz.ch/cvl/DIV2K/{name}
    else:
        print(f'{name} already exists')
# Out:
# DIV2K_train_LR_bicubic_X2.zip already exists
# DIV2K_train_LR_unknown_X2.zip already exists
# DIV2K_valid_LR_bicubic_X2.zip already exists
# DIV2K_valid_LR_unknown_X2.zip already exists
# DIV2K_train_LR_bicubic_X3.zip already exists
# DIV2K_train_LR_unknown_X3.zip already exists
# DIV2K_valid_LR_bicubic_X3.zip already exists
# DIV2K_valid_LR_unknown_X3.zip already exists
# DIV2K_train_LR_bicubic_X4.zip already exists
# DIV2K_train_LR_unknown_X4.zip already exists
# DIV2K_valid_LR_bicubic_X4.zip already exists
# DIV2K_valid_LR_unknown_X4.zip already exists
# DIV2K_train_LR_x8.zip already exists
# DIV2K_train_LR_mild.zip already exists
# DIV2K_train_LR_difficult.zip already exists
# DIV2K_train_LR_wild.zip already exists
# DIV2K_valid_LR_x8.zip already exists
# DIV2K_valid_LR_mild.zip already exists
# DIV2K_valid_LR_difficult.zip already exists
# DIV2K_valid_LR_wild.zip already exists
# DIV2K_train_HR.zip already exists
# DIV2K_valid_HR.zip already exists

# %%
for name in names:
    filename = os.path.join(DATA_PATH, name)
    foldername = filename.strip('.zip')
    if not os.path.exists(foldername):
        # !unzip {filename} -d {foldername}
    else:
        print(f'{name} already exists')
# Out:
# Archive:  /gpfs/gpfs0/b.shirokikh/data/SR/DIV2K/DIV2K_train_LR_bicubic_X2.zip
#    creating: /gpfs/gpfs0/b.shirokikh/data/SR/DIV2K/DIV2K_train_LR_bicubic_X2/DIV2K_train_LR_bicubic/X2/
#   inflating: /gpfs/gpfs0/b.shirokikh/data/SR/DIV2K/DIV2K_train_LR_bicubic_X2/DIV2K_train_LR_bicubic/X2/0261x2.png
#   inflating: /gpfs/gpfs0/b.shirokikh/data/SR/DIV2K/DIV2K_train_LR_bicubic_X2/DIV2K_train_LR_bicubic/X2/0229x2.png
#   inflating: /gpfs/gpfs0/b.shirokikh/data/SR/DIV2K/DIV2K_train_LR_bicubic_X2/DIV2K_train_LR_bicubic/X2/0188x2.png
#   inflating: /gpfs/gpfs0/b.shirokikh/data/SR/DIV2K/DIV2K_train_LR_bicubic_X2/DIV2K_train_LR_bicubic/X2/0711x2.png
#   inflating: /gpfs/gpfs0/b.shirokikh/data/SR/DIV2K/DIV2K_train_LR_bicubic_X2/DIV2K_train_LR_bicubic/X2/0187x2.png
#   inflating: /gpfs/gpfs0/b.shirokikh/data/SR/DIV2K/DIV2K_train_LR_bicubic_X2/DIV2K_train_LR_bicubic/X2/0198x2.png
#   inflating: /gpfs/gpfs0/b.shirokikh/data/SR/DIV2K/DIV2K_train_LR_bicubic_X2/DIV2K_train_LR_bicubic/X2/0770x2.png
# ...

# %% [markdown]
# ### LapSRN (several datasets)

# %%
# testing = set5 set14 bsds100 urban100 manga109 historical
DATA_PATH = '/gpfs/gpfs0/b.shirokikh/data/SR/LapSRN/'
os.makedirs(DATA_PATH, exist_ok=True, mode=0o770)

# %%
names = [
    'SR_testing_datasets.zip',
    'LapSRN_results.zip'
]

# %%
for name in names:
    filename = os.path.join(DATA_PATH, name)
    if not os.path.exists(filename):
        # !wget -O {filename} -t inf http://vllab.ucmerced.edu/wlai24/LapSRN/results/{name}
    else:
        print(f'{name} already exists')
# Out:
# --2020-05-13 16:54:54--  http://vllab.ucmerced.edu/wlai24/LapSRN/results/SR_testing_datasets.zip
# Resolving vllab.ucmerced.edu (vllab.ucmerced.edu)... 169.236.184.69
# Connecting to vllab.ucmerced.edu (vllab.ucmerced.edu)|169.236.184.69|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 317190619 (302M) [application/zip]
# Saving to: ‘/gpfs/gpfs0/b.shirokikh/data/SR/LapSRN/SR_testing_datasets.zip’
#
# 100%[======================================>] 317 190 619 9,90MB/s   in 56s
#
# 2020-05-13 16:55:50 (5,45 MB/s) - ‘/gpfs/gpfs0/b.shirokikh/data/SR/LapSRN/SR_testing_datasets.zip’ saved [317190619/317190619]
#
# --2020-05-13 16:55:50--  http://vllab.ucmerced.edu/wlai24/LapSRN/results/LapSRN_results.zip
# Resolving vllab.ucmerced.edu (vllab.ucmerced.edu)... 169.236.184.69
# Connecting to vllab.ucmerced.edu (vllab.ucmerced.edu)|169.236.184.69|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3901216426 (3,6G) [application/zip]
# ...

# %% [markdown]
# ### Flickr2K

# %%
DATA_PATH = '/gpfs/gpfs0/b.shirokikh/data/SR/'
name = 'Flickr2K.tar'
filename = os.path.join(DATA_PATH, name)
if not os.path.exists(filename):
    # !wget -O {filename} -t inf http://cv.snu.ac.kr/research/EDSR/{name}
else:
    print(f'{name} already exists')
# Out:
# --2020-05-13 17:40:13--  http://cv.snu.ac.kr/research/EDSR/Flickr2K.tar
# Resolving cv.snu.ac.kr (cv.snu.ac.kr)... 147.46.116.247
# Connecting to cv.snu.ac.kr (cv.snu.ac.kr)|147.46.116.247|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cv.snu.ac.kr/research/EDSR/Flickr2K.tar [following]
# --2020-05-13 17:40:14--  https://cv.snu.ac.kr/research/EDSR/Flickr2K.tar
# Connecting to cv.snu.ac.kr (cv.snu.ac.kr)|147.46.116.247|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21542973440 (20G) [application/x-tar]
# Saving to: ‘/gpfs/gpfs0/b.shirokikh/data/SR/Flickr2K.tar’
#
# 23% [=======>                             ] 5 052 030 976 1,63MB/s  eta 80m 15s
